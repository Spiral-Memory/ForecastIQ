# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

# %%
df = pd.read_csv('wptw.csv')
df
# Out:
# C:\Users\zisha\AppData\Local\Temp\ipykernel_21064\1743840569.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('wptw.csv')
#          STORE         UPC  WEEK  MOVE  PRICE  QTY SALE  PROFIT  OK  \
# 0            2  1122542322   336     0   0.00    1  NaN    0.00   1
# 1            2  1122542322   337     4   1.59    1  NaN    6.60   1
# 2            2  1122542322   338    22   1.59    1  NaN    6.60   1
# 3            2  1122542322   339    36   1.59    1  NaN    6.60   1
# 4            2  1122542322   344    29   1.79    1  NaN   22.78   1
# ...        ...         ...   ...   ...    ...  ...  ...     ...  ..
# 1847012    139  7572536605   395     0   0.00    1  NaN    0.00   1
# 1847013    139  7572536605   396     0   0.00    1  NaN    0.00   1
# 1847014    139  7572536605   397     0   0.00    1  NaN    0.00   1
# 1847015    139  7572536605   398     0   0.00    1  NaN    0.00   1
# 1847016    139  7572536605   399     0   0.00    1  NaN    0.00   1
#
#                 PRICE_HEX        PROFIT_HEX
# 0        0000000000000000  0000000000000000
# 1        3FF970A3D70A3D71  401A666666666666
# 2        3FF970A3D70A3D71  401A666666666666
# 3        3FF970A3D70A3D71  401A666666666666
# 4        3FFCA3D70A3D70A4  4036C7AE147AE148
# ...                   ...               ...
# 1847012  0000000000000000  0000000000000000
# 1847013  0000000000000000  0000000000000000
# 1847014  0000000000000000  0000000000000000
# 1847015  0000000000000000  0000000000000000
# 1847016  0000000000000000  0000000000000000
#
# [1847017 rows x 11 columns]

# %%
selected_df = df[(df['UPC'] == 3700063527) & (df['STORE'] == 112)][['WEEK', 'MOVE']]

# %%
# Remove any noise
selected_df['MOVE'] = selected_df['MOVE'][(selected_df['MOVE'] - selected_df['MOVE'].mean()).abs() < 3 * selected_df['MOVE'].std()]
selected_df = selected_df.dropna()

# %%
# Add missing weeks
max_week = selected_df['WEEK'].max()
all_weeks = range(1, max_week + 1)
missing_weeks = set(all_weeks) - set(selected_df['WEEK'])
missing_data = [{'WEEK': week, 'MOVE': selected_df['MOVE'].mean()} for week in missing_weeks]
missing_df = pd.DataFrame(missing_data)
selected_df = pd.concat([selected_df, missing_df]).sort_values('WEEK').reset_index(drop=True)
selected_df['MOVE'] = selected_df['MOVE'].fillna(selected_df['MOVE'].mean())

# %%
data = selected_df

# %%
print(data.head(30))
# Out:
#     WEEK   MOVE
# 0      1   85.0
# 1      2   89.0
# 2      3   98.0
# 3      4   75.0
# 4      5  114.0
# 5      6   10.0
# 6      7  123.0
# 7      8  103.0
# 8      9   98.0
# 9     10  113.0
# 10    11   56.0
# 11    12   91.0
# 12    13   85.0
# 13    14  106.0
# 14    15  111.0
# 15    16   16.0
# 16    17   91.0
# 17    18   89.0
# 18    19   80.0
# 19    20   66.0
# 20    21   91.0
# 21    22   77.0
# 22    23   95.0
# 23    24   93.0
# 24    25   76.0
# 25    26   53.0
# 26    27   67.0
# 27    28   70.0
# 28    29   19.0
# 29    30   74.0

# %%
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda:0'

# %%
plt.figure(figsize=(12, 6))
plt.plot(data['WEEK'], data['MOVE'], color = '#6699ff')

# %%
from copy import deepcopy as dc
import pandas as pd

def prepare_dataframe_for_lstm(df, n_steps):
    df = dc(df)
    
    df.set_index('WEEK', inplace=True) 
    
    for i in range(1, n_steps+1):
        df[f'Move(t-{i})'] = df['MOVE'].shift(i)
        
    df.dropna(inplace=True)
    
    return df

lookback = 7
shifted_df = prepare_dataframe_for_lstm(data, lookback)
shifted_df
# Out:
#        MOVE  Move(t-1)  Move(t-2)   Move(t-3)   Move(t-4)   Move(t-5)  \
# WEEK
# 8     103.0      123.0       10.0  114.000000   75.000000   98.000000
# 9      98.0      103.0      123.0   10.000000  114.000000   75.000000
# 10    113.0       98.0      103.0  123.000000   10.000000  114.000000
# 11     56.0      113.0       98.0  103.000000  123.000000   10.000000
# 12     91.0       56.0      113.0   98.000000  103.000000  123.000000
# ...     ...        ...        ...         ...         ...         ...
# 395    70.0       45.0       46.0   60.152455   51.000000   43.000000
# 396    50.0       70.0       45.0   46.000000   60.152455   51.000000
# 397    44.0       50.0       70.0   45.000000   46.000000   60.152455
# 398    59.0       44.0       50.0   70.000000   45.000000   46.000000
# 399    56.0       59.0       44.0   50.000000   70.000000   45.000000
#
#        Move(t-6)   Move(t-7)
# WEEK
# 8      89.000000   85.000000
# 9      98.000000   89.000000
# 10     75.000000   98.000000
# 11    114.000000   75.000000
# 12     10.000000  114.000000
# ...          ...         ...
# 395    48.000000   42.000000
# 396    43.000000   48.000000
# 397    51.000000   43.000000
# 398    60.152455   51.000000
# 399    46.000000   60.152455
#
# [392 rows x 8 columns]

# %%
shifted_df_as_np = shifted_df.to_numpy()

shifted_df_as_np
# Out:
# array([[103.        , 123.        ,  10.        , ...,  98.        ,
#          89.        ,  85.        ],
#        [ 98.        , 103.        , 123.        , ...,  75.        ,
#          98.        ,  89.        ],
#        [113.        ,  98.        , 103.        , ..., 114.        ,
#          75.        ,  98.        ],
#        ...,
#        [ 44.        ,  50.        ,  70.        , ...,  60.15245478,
#          51.        ,  43.        ],
#        [ 59.        ,  44.        ,  50.        , ...,  46.        ,
#          60.15245478,  51.        ],
#        [ 56.        ,  59.        ,  44.        , ...,  45.        ,
#          46.        ,  60.15245478]])

# %%
shifted_df_as_np.shape
# Out:
# (392, 8)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(-1, 1))
shifted_df_as_np = scaler.fit_transform(shifted_df_as_np)

shifted_df_as_np
# Out:
# array([[ 0.57251908,  0.8778626 , -0.84732824, ...,  0.49618321,
#          0.35877863,  0.29770992],
#        [ 0.49618321,  0.57251908,  0.8778626 , ...,  0.14503817,
#          0.49618321,  0.35877863],
#        [ 0.72519084,  0.49618321,  0.57251908, ...,  0.74045802,
#          0.14503817,  0.49618321],
#        ...,
#        [-0.32824427, -0.23664122,  0.06870229, ..., -0.08164191,
#         -0.22137405, -0.34351145],
#        [-0.09923664, -0.32824427, -0.23664122, ..., -0.29770992,
#         -0.08164191, -0.22137405],
#        [-0.14503817, -0.09923664, -0.32824427, ..., -0.3129771 ,
#         -0.29770992, -0.08164191]])

# %%
X = shifted_df_as_np[:, 1:]
y = shifted_df_as_np[:, 0]

X.shape, y.shape
# Out:
# ((392, 7), (392,))

# %%
X = dc(np.flip(X, axis=1))
X
# Out:
# array([[ 0.29770992,  0.35877863,  0.49618321, ...,  0.74045802,
#         -0.84732824,  0.8778626 ],
#        [ 0.35877863,  0.49618321,  0.14503817, ..., -0.84732824,
#          0.8778626 ,  0.57251908],
#        [ 0.49618321,  0.14503817,  0.74045802, ...,  0.8778626 ,
#          0.57251908,  0.49618321],
#        ...,
#        [-0.34351145, -0.22137405, -0.08164191, ..., -0.3129771 ,
#          0.06870229, -0.23664122],
#        [-0.22137405, -0.08164191, -0.29770992, ...,  0.06870229,
#         -0.23664122, -0.32824427],
#        [-0.08164191, -0.29770992, -0.3129771 , ..., -0.23664122,
#         -0.32824427, -0.09923664]])

# %%
split_index = int(len(X) * 0.80)

split_index
# Out:
# 313

# %%
X_train = X[:split_index]
X_test = X[split_index:]

y_train = y[:split_index]
y_test = y[split_index:]

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((313, 7), (79, 7), (313,), (79,))

# %%
X_train = X_train.reshape((-1, lookback, 1))
X_test = X_test.reshape((-1, lookback, 1))

y_train = y_train.reshape((-1, 1))
y_test = y_test.reshape((-1, 1))

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((313, 7, 1), (79, 7, 1), (313, 1), (79, 1))

# %%
X_train = torch.tensor(X_train).float()
y_train = torch.tensor(y_train).float()
X_test = torch.tensor(X_test).float()
y_test = torch.tensor(y_test).float()

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (torch.Size([313, 7, 1]),
#  torch.Size([79, 7, 1]),
#  torch.Size([313, 1]),
#  torch.Size([79, 1]))

# %%
from torch.utils.data import Dataset

class SalesDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]
    
train_dataset = SalesDataset(X_train, y_train)
test_dataset = SalesDataset(X_test, y_test)

# %%
train_dataset

# %%
from torch.utils.data import DataLoader

batch_size = 16

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
for _, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([16, 7, 1]) torch.Size([16, 1])

# %%
class SimpleRNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_stacked_layers):
        super(SimpleRNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers

        self.rnn = nn.RNN(input_size, hidden_size, num_stacked_layers, batch_first=True)

        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        batch_size = x.size(0)
        h0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)

        out, _ = self.rnn(x, h0)
        out = self.fc(out[:, -1, :])
        return out

model = SimpleRNN(1, 4, 1)
model.to(device)
model
# Out:
# SimpleRNN(
#   (rnn): RNN(1, 4, batch_first=True)
#   (fc): Linear(in_features=4, out_features=1, bias=True)
# )

# %%
import matplotlib.pyplot as plt

train_losses = []
val_losses = []

def train_one_epoch():
    model.train(True)
    print(f'Epoch: {epoch + 1}')
    running_loss = 0.0

    for batch_index, batch in enumerate(train_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        output = model(x_batch)
        loss = loss_function(output, y_batch)
        running_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch_index % 10 == 9:  # print every 100 batches
            avg_loss_across_batches = running_loss / 100
            print('Batch {0}, Loss: {1:.3f}'.format(batch_index + 1, avg_loss_across_batches))
            running_loss = 0.0
    train_losses.append(avg_loss_across_batches)
    print()

def validate_one_epoch():
    model.train(False)
    running_loss = 0.0

    for batch_index, batch in enumerate(test_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        with torch.no_grad():
            output = model(x_batch)
            loss = loss_function(output, y_batch)
            running_loss += loss.item()

    avg_loss_across_batches = running_loss / len(test_loader)

    print('Val Loss: {0:.3f}'.format(avg_loss_across_batches))
    val_losses.append(avg_loss_across_batches)
    print('***************************************************')
    print()

learning_rate = 0.001
num_epochs = 30
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_losses = []
val_losses = []

for epoch in range(num_epochs):
    train_one_epoch()
    validate_one_epoch()

# Plotting
epochs = range(1, num_epochs + 1)
plt.plot(epochs, train_losses, label='Training Loss')
plt.plot(epochs, val_losses, label='Validation Loss')
plt.title('Training and Validation Losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch: 1
# Batch 10, Loss: 0.031
# Batch 20, Loss: 0.026
#
# Val Loss: 0.169
# ***************************************************
#
# Epoch: 2
# Batch 10, Loss: 0.023
# Batch 20, Loss: 0.020
#
# Val Loss: 0.108
# ***************************************************
#
# Epoch: 3
# Batch 10, Loss: 0.017
# Batch 20, Loss: 0.015
#
# Val Loss: 0.065
# ***************************************************
#
# Epoch: 4
# Batch 10, Loss: 0.014
# Batch 20, Loss: 0.011
#
# Val Loss: 0.040
# ***************************************************
#
# Epoch: 5
# Batch 10, Loss: 0.011
# Batch 20, Loss: 0.009
#
# Val Loss: 0.028
# ***************************************************
#
# Epoch: 6
# Batch 10, Loss: 0.010
# Batch 20, Loss: 0.008
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 7
# Batch 10, Loss: 0.009
# Batch 20, Loss: 0.007
#
# Val Loss: 0.022
# ***************************************************
#
# Epoch: 8
# Batch 10, Loss: 0.007
# Batch 20, Loss: 0.009
#
# Val Loss: 0.022
# ***************************************************
#
# Epoch: 9
# Batch 10, Loss: 0.008
# Batch 20, Loss: 0.008
#
# Val Loss: 0.022
# ***************************************************
#
# Epoch: 10
# Batch 10, Loss: 0.007
# Batch 20, Loss: 0.008
#
# Val Loss: 0.022
# ***************************************************
#
# Epoch: 11
# Batch 10, Loss: 0.007
# Batch 20, Loss: 0.007
#
# Val Loss: 0.022
# ***************************************************
#
# Epoch: 12
# Batch 10, Loss: 0.007
# Batch 20, Loss: 0.006
#
# Val Loss: 0.022
# ***************************************************
#
# Epoch: 13
# Batch 10, Loss: 0.007
# Batch 20, Loss: 0.005
#
# Val Loss: 0.022
# ***************************************************
#
# Epoch: 14
# Batch 10, Loss: 0.006
# Batch 20, Loss: 0.005
#
# Val Loss: 0.022
# ***************************************************
#
# Epoch: 15
# Batch 10, Loss: 0.005
# Batch 20, Loss: 0.006
#
# Val Loss: 0.022
# ***************************************************
#
# Epoch: 16
# Batch 10, Loss: 0.005
# Batch 20, Loss: 0.007
#
# Val Loss: 0.022
# ***************************************************
#
# Epoch: 17
# Batch 10, Loss: 0.005
# Batch 20, Loss: 0.006
#
# Val Loss: 0.023
# ***************************************************
#
# Epoch: 18
# Batch 10, Loss: 0.006
# Batch 20, Loss: 0.005
#
# Val Loss: 0.023
# ***************************************************
#
# Epoch: 19
# Batch 10, Loss: 0.005
# Batch 20, Loss: 0.005
#
# Val Loss: 0.023
# ***************************************************
#
# Epoch: 20
# Batch 10, Loss: 0.006
# Batch 20, Loss: 0.005
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 21
# Batch 10, Loss: 0.005
# Batch 20, Loss: 0.005
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 22
# Batch 10, Loss: 0.005
# Batch 20, Loss: 0.006
#
# Val Loss: 0.023
# ***************************************************
#
# Epoch: 23
# Batch 10, Loss: 0.007
# Batch 20, Loss: 0.004
#
# Val Loss: 0.023
# ***************************************************
#
# Epoch: 24
# Batch 10, Loss: 0.006
# Batch 20, Loss: 0.005
#
# Val Loss: 0.023
# ***************************************************
#
# Epoch: 25
# Batch 10, Loss: 0.006
# Batch 20, Loss: 0.005
#
# Val Loss: 0.023
# ***************************************************
#
# Epoch: 26
# Batch 10, Loss: 0.006
# Batch 20, Loss: 0.004
#
# Val Loss: 0.023
# ***************************************************
#
# Epoch: 27
# Batch 10, Loss: 0.006
# Batch 20, Loss: 0.005
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 28
# Batch 10, Loss: 0.005
# Batch 20, Loss: 0.006
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 29
# Batch 10, Loss: 0.005
# Batch 20, Loss: 0.006
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 30
# Batch 10, Loss: 0.004
# Batch 20, Loss: 0.006
#
# Val Loss: 0.023
# ***************************************************

# %%
with torch.no_grad():
    predicted = model(X_train.to(device)).to('cpu').numpy()

plt.figure(figsize=(12, 8))
plt.plot(y_train, label='Moves', color = '#6699ff')
plt.plot(predicted, label='Forecasted', color = 'green')
plt.xlabel('Week')
plt.ylabel('Moves Over Time')
plt.legend()
plt.show()

# %%
train_predictions = predicted.flatten()

dummies = np.zeros((X_train.shape[0], lookback+1))
dummies[:, 0] = train_predictions
dummies = scaler.inverse_transform(dummies)

train_predictions = dc(dummies[:, 0])
train_predictions
# Out:
# array([ 87.20706549,  91.69963926,  93.19506344,  98.67945927,
#         80.20955989,  85.49428031,  85.47317667,  93.15087874,
#         97.75178555,  61.07390971,  74.77227195,  80.22915849,
#         79.37270343,  72.62562855,  80.02800928,  77.23651814,
#         85.81884606,  88.02093458,  82.36092238,  68.83296892,
#         67.60418969,  67.05386667,  46.77346823,  58.03221332,
#         61.93289072,  70.29779566,  76.11154075,  84.2449611 ,
#         80.03808285,  79.52953325,  83.15671742,  95.04041834,
#         94.68616773,  85.78365056,  91.63349593, 102.75724539,
#         93.93247065,  91.87613796,  90.72383964,  95.76813751,
#         96.45926352,  86.4484141 ,  83.77870564,  91.93976705,
#         88.65401241,  91.36362863,  91.49747889,  88.25531553,
#         86.20216468,  78.71706964,  54.62595119,  58.75238586,
#         61.024718  ,  64.54621318,  69.94446788,  79.37846784,
#         76.4424292 ,  83.8901073 ,  81.46209413,  91.70986801,
#         80.00744246,  74.7179766 ,  72.60629445,  64.4736759 ,
#         75.25446787,  75.05683528,  83.62171575,  89.12699074,
#         88.66600972,  91.77879693,  89.21406592,  84.87757434,
#         82.53168595,  81.59605566,  86.4722428 ,  77.20688307,
#         75.65937813,  62.85140347,  63.62214782,  68.36093734,
#         68.65811824,  73.46821086,  68.80999083,  73.84006751,
#         75.15270446,  74.93133199,  93.08840722,  91.06451958,
#         93.19163759,  91.00478093,  90.02393526,  90.25295977,
#         92.19621594,  98.77669099,  89.23125765,  94.42370456,
#         81.94943565,  81.0982853 ,  83.42854458,  77.77137066,
#         78.29632238,  65.87676948,  59.55159796,  58.9762999 ,
#         54.58166303,  56.29208037,  54.66159371,  65.63480921,
#         66.45194018,  65.75579935,  68.62596892,  70.45809623,
#         71.53419765,  83.49049491,  66.52218184,  62.0662315 ,
#         66.10331343,  56.93675339,  60.92783277,  55.7618874 ,
#         48.57833366,  49.34002635,  55.17726927,  59.39314404,
#         52.81366405,  56.85332659,  51.65656954,  49.61545505,
#         57.53311263,  55.79975526,  53.83056608,  59.77133657,
#         48.75917372,  51.63133731,  53.30912806,  55.85752039,
#         53.34739414,  49.40308154,  50.02824184,  48.63146657,
#         45.02514593,  48.91944501,  54.23459597,  48.07584617,
#         49.63509464,  45.47213463,  45.16618365,  47.35675311,
#         47.11430824,  48.25906187,  47.19433847,  43.54779971,
#         46.08563729,  41.63773818,  44.74860457,  46.40718712,
#         45.92767528,  47.53140712,  47.76266088,  48.20651653,
#         55.2690528 ,  57.00147368,  50.40228626,  45.55767551,
#         46.60249384,  53.06225984,  50.14761764,  50.25346376,
#         45.68414116,  48.92848887,  47.42506127,  56.96157959,
#         48.98387834,  52.47988266,  51.73302752,  54.96719137,
#         80.66932379,  61.7077059 ,  56.87868375,  56.87197845,
#         53.05415101,  46.39583789,  44.5437855 ,  46.20255935,
#         44.12876751,  49.99935928,  52.7773266 ,  51.09563956,
#         49.35956834,  49.02895318,  47.91008961,  49.71446508,
#         52.97150503,  44.37060724,  48.92912719,  43.64562485,
#         44.65397884,  45.44010341,  47.60518883,  50.84826185,
#         47.47691363,  48.27619699,  46.97316121,  47.17383412,
#         46.60566202,  43.38450664,  41.79241684,  42.8318436 ,
#         43.42343056,  48.59815089,  49.16287176,  47.20966598,
#         37.86314675,  41.8543984 ,  45.44980121,  49.85433742,
#         59.68659408,  61.23786062,  52.97589324,  45.2047113 ,
#         49.4095194 ,  51.1350593 ,  44.91579978,  42.00558874,
#         46.31506002,  42.033425  ,  46.41167489,  48.069217  ,
#         46.76142797,  46.75092398,  45.11584413,  43.23734534,
#         44.63385904,  44.63793102,  46.50022973,  45.17532901,
#         45.66880779,  46.29645111,  47.65250462,  47.53339626,
#         47.86298269,  44.42086282,  44.79593012,  45.5114314 ,
#         46.79693775,  43.11966002,  47.2850152 ,  46.13788201,
#         48.87011275,  46.49057879,  42.95510788,  47.52440511,
#         45.7071012 ,  42.72537282,  42.891918  ,  46.18781355,
#         48.93349198,  46.21848419,  44.51736057,  46.83983409,
#         49.30771403,  46.39851025,  44.60603254,  43.56067935,
#         49.41471186,  47.12291288,  50.93390033,  49.93481077,
#         53.57795101,  52.23971583,  50.91740549,  53.81580271,
#         55.10671429,  51.30742159,  42.5074223 ,  46.01343673,
#         46.62061083,  43.57788473,  45.24471861,  45.55349031,
#         46.79461285,  47.81024605,  47.59696484,  42.27804056,
#         49.17235288,  50.04250549,  47.86979926,  47.79071772,
#         48.56972121,  50.10707352,  49.1842604 ,  51.80553259,
#         48.80298167,  46.76744224,  49.55948971,  55.45321135,
#         53.68188217,  49.48761711,  55.4588196 ,  65.01143796,
#         64.42604193,  60.62684488,  57.29115626,  60.20747088,
#         58.74672198,  49.33715683,  51.56057543,  45.000716  ,
#         45.64444618,  50.86887552,  47.07193895,  54.13409457,
#         56.01545116])

# %%
dummies = np.zeros((X_train.shape[0], lookback+1))
dummies[:, 0] = y_train.flatten()
dummies = scaler.inverse_transform(dummies)

new_y_train = dc(dummies[:, 0])
new_y_train
# Out:
# array([102.99999869,  98.00000069, 112.9999986 ,  55.99999969,
#         91.00000036,  84.99999924, 105.99999827, 111.00000018,
#         15.99999908,  91.00000036,  88.99999999,  80.00000026,
#         66.        ,  91.00000036,  76.9999997 ,  94.99999915,
#         93.00000073,  75.99999952,  53.00000011,  67.00000004,
#         69.99999986,  18.99999866,  74.00000012,  72.99999993,
#         84.99999924,  86.0000004 ,  96.00000031,  75.99999952,
#         76.9999997 ,  88.00000077, 113.99999976,  99.00000185,
#         74.00000012,  99.99999911, 131.        ,  86.0000004 ,
#         88.99999999,  89.9999992 , 105.99999827, 102.00000143,
#         72.99999993,  80.00000026, 103.99999985,  86.0000004 ,
#         96.00000031,  93.99999994,  84.99999924,  83.00000082,
#         68.99999992,  25.99999899,  65.        ,  68.99999992,
#         74.00000012,  81.00000045,  93.99999994,  75.00000031,
#         91.99999957,  79.00000007, 105.99999827,  66.        ,
#         67.99999998,  72.00000023,  56.99999988,  91.00000036,
#         77.99999989,  96.99999952,  98.00000069,  88.99999999,
#         96.99999952,  86.0000004 ,  79.00000007,  79.00000007,
#         81.00000045,  93.99999994,  67.00000004,  75.00000031,
#         49.99999955,  67.00000004,  77.99999989,  72.99999993,
#         83.00000082,  66.        ,  81.99999966,  77.99999989,
#         75.99999952, 119.00000167,  91.99999957,  98.00000069,
#         88.99999999,  88.99999999,  91.00000036,  96.00000031,
#        115.00000092,  77.99999989, 102.99999869,  66.        ,
#         79.00000007,  86.99999961,  72.00000023,  81.00000045,
#         53.00000011,  55.00000048,  61.00000014,  51.99999993,
#         62.00000008,  55.99999969,  84.00000003,  72.00000023,
#         67.99999998,  75.00000031,  75.00000031,  75.00000031,
#         99.00000185,  49.00000034,  58.00000007,  74.00000012,
#         49.00000034,  68.99999992,  53.00000011,  39.00000043,
#         49.00000034,  66.        ,  69.99999986,  46.99999997,
#         65.        ,  46.99999997,  46.00000076,  71.00000005,
#         58.00000007,  54.0000003 ,  71.00000005,  34.99999969,
#         55.00000048,  58.00000007,  63.00000002,  53.00000011,
#         44.00000039,  50.99999974,  46.00000076,  34.99999969,
#         53.00000011,  65.        ,  39.99999964,  50.99999974,
#         36.00000085,  39.00000043,  47.99999918,  44.9999996 ,
#         49.00000034,  44.00000039,  31.00000089,  44.9999996 ,
#         24.00000057,  42.00000001,  46.00000076,  42.00000001,
#         47.99999918,  46.99999997,  47.99999918,  67.99999998,
#         63.99999996,  42.99999923,  34.00000048,  44.00000039,
#         63.99999996,  47.99999918,  50.99999974,  36.00000085,
#         51.99999993,  44.00000039,  72.99999993,  39.99999964,
#         58.00000007,  53.00000011,  62.00000008, 115.99999818,
#         42.99999923,  51.99999993,  58.99999977,  49.99999955,
#         34.00000048,  34.99999969,  44.9999996 ,  34.99999969,
#         58.00000007,  59.99999995,  50.99999974,  46.99999997,
#         47.99999918,  44.9999996 ,  51.99999993,  59.99999995,
#         28.00000131,  53.00000011,  29.99999973,  39.00000043,
#         42.00000001,  49.00000034,  56.99999988,  42.00000001,
#         47.99999918,  42.99999923,  44.9999996 ,  42.99999923,
#         31.00000089,  27.00000015,  34.00000048,  36.00000085,
#         55.00000048,  50.99999974,  42.99999923,   0.        ,
#         31.99999815,  46.00000076,  56.99999988,  77.99999989,
#         68.99999992,  44.9999996 ,  28.99999857,  53.00000011,
#         55.00000048,  31.99999815,  25.99999899,  47.99999918,
#         25.99999899,  47.99999918,  49.99999955,  42.99999923,
#         44.00000039,  37.99999927,  31.99999815,  39.99999964,
#         39.00000043,  46.00000076,  39.00000043,  42.00000001,
#         44.00000039,  47.99999918,  46.00000076,  46.99999997,
#         34.00000048,  39.00000043,  42.00000001,  46.00000076,
#         29.99999973,  49.99999955,  42.00000001,  51.99999993,
#         41.0000008 ,  28.99999857,  50.99999974,  39.99999964,
#         28.99999857,  32.99999931,  46.99999997,  53.00000011,
#         39.99999964,  36.00000085,  46.99999997,  53.00000011,
#         39.99999964,  36.00000085,  34.00000048,  56.99999988,
#         42.99999923,  56.99999988,  49.99999955,  61.00000014,
#         53.00000011,  49.99999955,  60.15245473,  60.15245473,
#         47.99999918,  21.00000098,  44.9999996 ,  44.9999996 ,
#         31.99999815,  42.00000001,  42.00000001,  46.00000076,
#         47.99999918,  46.00000076,  25.00000173,  56.99999988,
#         53.00000011,  44.00000039,  46.00000076,  49.00000034,
#         53.00000011,  47.99999918,  56.99999988,  44.9999996 ,
#         41.0000008 ,  53.00000011,  67.00000004,  55.00000048,
#         44.00000039,  66.        ,  81.99999966,  67.99999998,
#         58.99999977,  55.99999969,  67.00000004,  59.99999995,
#         37.00000006,  55.00000048,  31.99999815,  41.0000008 ,
#         58.99999977,  41.0000008 ,  66.        ,  63.00000002,
#         44.00000039])

# %%
plt.figure(figsize=(12, 8))
plt.plot(new_y_train, label='Moves', color = '#6699ff')
plt.plot(train_predictions, label='Forecasted', color ='green')
plt.xlabel('Week')
plt.ylabel('Moves Over Time')
plt.legend()
plt.show()

# %%
test_predictions = model(X_test.to(device)).detach().cpu().numpy().flatten()

dummies = np.zeros((X_test.shape[0], lookback+1))
dummies[:, 0] = test_predictions
dummies = scaler.inverse_transform(dummies)

test_predictions = dc(dummies[:, 0])
test_predictions
# Out:
# array([50.25511324, 50.61229974, 50.48495372, 61.47483486, 53.2252679 ,
#        54.47977567, 49.02201168, 52.8504329 , 55.66089799, 52.59681644,
#        52.33031642, 51.55807289, 55.95254433, 54.94096945, 55.76808907,
#        53.39098541, 50.114382  , 51.08913141, 54.16202258, 55.07613344,
#        55.75647631, 56.11690517, 56.39948618, 56.66318695, 58.3446578 ,
#        62.11158743, 60.71478092, 59.36893957, 59.90852484, 68.65937439,
#        66.68193584, 63.73186877, 62.36894989, 61.20850858, 63.2126678 ,
#        68.2935486 , 62.67118709, 60.23043775, 68.56426016, 66.6191715 ,
#        61.95035573, 58.06533672, 55.04975341, 61.42867371, 59.02965339,
#        71.63593129, 66.24832455, 64.59635555, 61.31991025, 54.35622638,
#        55.84393801, 56.27545279, 56.87924984, 57.02965936, 56.74939738,
#        53.59732513, 60.66170365, 64.53386645, 63.89342646, 58.13351409,
#        49.28357105, 47.84105334, 51.09439805, 54.26095843, 55.3935664 ,
#        51.32417801, 48.62172583, 49.46655446, 47.18857601, 48.18435684,
#        46.89104423, 48.86473484, 52.58688635, 49.39056107, 48.12954322,
#        56.15391217, 52.15220729, 49.01283118, 52.63603511])

# %%
dummies = np.zeros((X_test.shape[0], lookback+1))
dummies[:, 0] = y_test.flatten()
dummies = scaler.inverse_transform(dummies)

new_y_test = dc(dummies[:, 0])
new_y_test
# Out:
# array([50.99999974, 50.99999974, 80.00000026, 46.00000076, 58.00000007,
#        42.00000001, 58.99999977, 63.00000002, 50.99999974, 54.0000003 ,
#        51.99999993, 65.        , 56.99999988, 59.99999995, 53.00000011,
#        46.00000076, 53.00000011, 61.00000014, 59.99999995, 60.15245473,
#        60.15245473, 60.15245473, 60.15245473, 63.99999996, 71.00000005,
#        63.00000002, 61.00000014, 63.99999996, 83.00000082, 67.99999998,
#        63.00000002, 63.99999996, 63.00000002, 68.99999992, 77.99999989,
#        60.15245473, 60.15245473, 81.99999966, 67.99999998, 58.99999977,
#        55.99999969, 54.0000003 , 72.99999993, 60.15245473, 91.00000036,
#        63.99999996, 65.        , 59.99999995, 46.99999997, 60.15245473,
#        60.15245473, 62.00000008, 61.00000014, 59.99999995, 51.99999993,
#        72.99999993, 74.00000012, 67.00000004, 54.0000003 , 37.00000006,
#        42.99999923, 55.99999969, 62.00000008, 61.00000014, 47.99999918,
#        44.00000039, 49.99999955, 42.00000001, 47.99999918, 42.99999923,
#        50.99999974, 60.15245473, 46.00000076, 44.9999996 , 69.99999986,
#        49.99999955, 44.00000039, 58.99999977, 55.99999969])

# %%
plt.figure(figsize=(12, 6))
plt.plot(new_y_test, label='Moves',color = '#6699ff')
plt.plot(test_predictions, label='Forecasted', color = 'green')
plt.xlabel('Week')
plt.ylabel('Moves Over Time')
plt.title("Simple RNN Model")
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
# report performance
mse = mean_squared_error(new_y_test, test_predictions)
print('MSE: '+str(mse))
mae = mean_absolute_error(new_y_test, test_predictions)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(new_y_test, test_predictions))
print('RMSE: '+str(rmse))
# Out:
# MSE: 100.72144153533988
# MAE: 7.509953872925496
# RMSE: 10.036007250661982

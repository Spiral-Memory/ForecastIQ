# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
from copy import deepcopy as dc
# Define the LSTM model
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_stacked_layers):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers

        self.lstm = nn.LSTM(input_size, hidden_size, num_stacked_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        batch_size = x.size(0)
        h0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)
        c0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)
        
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# Prepare the dataset
df = pd.read_csv('wptw.csv')
selected_df = df[(df['UPC'] == 3700063527) & (df['STORE'] == 112)][['WEEK', 'MOVE']]

selected_df['MOVE'] = selected_df['MOVE'][(selected_df['MOVE'] - selected_df['MOVE'].mean()).abs() < 3 * selected_df['MOVE'].std()]
selected_df = selected_df.dropna()

max_week = selected_df['WEEK'].max()
all_weeks = range(1, max_week + 1)
missing_weeks = set(all_weeks) - set(selected_df['WEEK'])
missing_data = [{'WEEK': week, 'MOVE': selected_df['MOVE'].mean()} for week in missing_weeks]
missing_df = pd.DataFrame(missing_data)
selected_df = pd.concat([selected_df, missing_df]).sort_values('WEEK').reset_index(drop=True)
selected_df['MOVE'] = selected_df['MOVE'].fillna(selected_df['MOVE'].mean())

data = selected_df

# Set device (GPU if available, otherwise CPU)
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# Visualize the data
plt.figure(figsize=(12, 6))
plt.plot(data['WEEK'], data['MOVE'], color='#6699ff')
plt.title("Original Data")
plt.show()

# Prepare the dataframe for LSTM
lookback = 7
shifted_df = dc(data)
shifted_df.set_index('WEEK', inplace=True)

for i in range(1, lookback+1):
    shifted_df[f'Move(t-{i})'] = shifted_df['MOVE'].shift(i)

shifted_df.dropna(inplace=True)
# Out:
# C:\Users\zisha\AppData\Local\Temp\ipykernel_23500\4157590796.py:32: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('wptw.csv')

# %%
# Scale the data
scaler = MinMaxScaler(feature_range=(-1, 1))
shifted_df_as_np = scaler.fit_transform(shifted_df.to_numpy())

X = shifted_df_as_np[:, 1:]
y = shifted_df_as_np[:, 0]

X = dc(np.flip(X, axis=1))

# %%
# Split the data into training and testing sets
split_index = int(len(X) * 0.80)

X_train = X[:split_index]
X_test = X[split_index:]
y_train = y[:split_index]
y_test = y[split_index:]

X_train = X_train.reshape((-1, lookback, 1))
X_test = X_test.reshape((-1, lookback, 1))
y_train = y_train.reshape((-1, 1))
y_test = y_test.reshape((-1, 1))

X_train = torch.tensor(X_train).float()
y_train = torch.tensor(y_train).float()
X_test = torch.tensor(X_test).float()
y_test = torch.tensor(y_test).float()

# Create PyTorch datasets and data loaders
class SalesDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]

# %%
batch_size = 16
train_loader = DataLoader(SalesDataset(X_train, y_train), batch_size=batch_size, shuffle=True)
test_loader = DataLoader(SalesDataset(X_test, y_test), batch_size=batch_size, shuffle=False)

# Train and evaluate an ensemble of LSTM models with random initializations and architectures
num_models = 10
models = []

train_losses = []  # Store training losses for each model
test_losses = []   # Store testing losses for each model

for i in range(num_models):
    # Randomly choose the number of hidden units, stacked layers, and learning rate
    hidden_size = np.random.choice([4, 8, 16])
    num_layers = np.random.choice([1, 2, 3])
    learning_rate = 10 ** np.random.uniform(-4, -2)

    model = LSTM(1, hidden_size, num_layers)
    model.to(device)

    # Randomly initialize the parameters
    for param in model.parameters():
        nn.init.uniform_(param, -0.08, 0.08)

    models.append((model, learning_rate))

# Training and evaluation loop
num_epochs = 30
loss_function = nn.MSELoss()

for model_idx, (model, learning_rate) in enumerate(models):
    print(f"Training Ensemble Model {model_idx + 1} with Learning Rate: {learning_rate}")

    model_losses_train = []  # Store training losses during training for each model

    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    for epoch in range(num_epochs):
        model.train(True)
        running_loss = 0.0
        
        for batch_index, batch in enumerate(train_loader):
            x_batch, y_batch = batch[0].to(device), batch[1].to(device)
            
            output = model(x_batch)
            loss = loss_function(output, y_batch)
            running_loss += loss.item()
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            if batch_index % 10 == 9:
                avg_loss_across_batches = running_loss / 10
                print(f'Ensemble Model {model_idx + 1}, Epoch {epoch + 1}, Batch {batch_index + 1}, Loss: {avg_loss_across_batches:.3f}')
                model_losses_train.append(avg_loss_across_batches)
                running_loss = 0.0
    
    train_losses.append(model_losses_train)

    # Evaluate the model on the test set
    model.train(False)
    running_loss = 0.0
    
    for batch_index, batch in enumerate(test_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)
        
        with torch.no_grad():
            output = model(x_batch)
            loss = loss_function(output, y_batch)
            running_loss += loss.item()

    avg_loss_across_batches = running_loss / len(test_loader)
    
    test_losses.append(avg_loss_across_batches)

    print(f'Ensemble Model {model_idx + 1}, Validation Loss: {avg_loss_across_batches:.3f}')
    print('***************************************************')

# Plot training and testing losses for each model
plt.figure(figsize=(12, 6))
for model_idx in range(num_models):
    num_batches_per_epoch_train = len(train_loader.dataset) // batch_size

    plt.plot(np.linspace(0, num_epochs, len(train_losses[model_idx])), train_losses[model_idx], label=f'Model {model_idx + 1} (Train)')

plt.title("Training  Losses for Each Model")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Training Ensemble Model 1 with Learning Rate: 0.003167705748504656
# Ensemble Model 1, Epoch 1, Batch 10, Loss: 0.118
# Ensemble Model 1, Epoch 1, Batch 20, Loss: 0.116
# Ensemble Model 1, Epoch 2, Batch 10, Loss: 0.121
# Ensemble Model 1, Epoch 2, Batch 20, Loss: 0.084
# Ensemble Model 1, Epoch 3, Batch 10, Loss: 0.073
# Ensemble Model 1, Epoch 3, Batch 20, Loss: 0.071
# Ensemble Model 1, Epoch 4, Batch 10, Loss: 0.069
# Ensemble Model 1, Epoch 4, Batch 20, Loss: 0.056
# Ensemble Model 1, Epoch 5, Batch 10, Loss: 0.069
# Ensemble Model 1, Epoch 5, Batch 20, Loss: 0.048
# Ensemble Model 1, Epoch 6, Batch 10, Loss: 0.069
# Ensemble Model 1, Epoch 6, Batch 20, Loss: 0.047
# Ensemble Model 1, Epoch 7, Batch 10, Loss: 0.066
# Ensemble Model 1, Epoch 7, Batch 20, Loss: 0.045
# Ensemble Model 1, Epoch 8, Batch 10, Loss: 0.050
# Ensemble Model 1, Epoch 8, Batch 20, Loss: 0.060
# Ensemble Model 1, Epoch 9, Batch 10, Loss: 0.052
# Ensemble Model 1, Epoch 9, Batch 20, Loss: 0.060
# Ensemble Model 1, Epoch 10, Batch 10, Loss: 0.060
# Ensemble Model 1, Epoch 10, Batch 20, Loss: 0.051
# Ensemble Model 1, Epoch 11, Batch 10, Loss: 0.053
# Ensemble Model 1, Epoch 11, Batch 20, Loss: 0.056
# Ensemble Model 1, Epoch 12, Batch 10, Loss: 0.047
# Ensemble Model 1, Epoch 12, Batch 20, Loss: 0.063
# Ensemble Model 1, Epoch 13, Batch 10, Loss: 0.054
# Ensemble Model 1, Epoch 13, Batch 20, Loss: 0.056
# Ensemble Model 1, Epoch 14, Batch 10, Loss: 0.057
# Ensemble Model 1, Epoch 14, Batch 20, Loss: 0.054
# Ensemble Model 1, Epoch 15, Batch 10, Loss: 0.048
# Ensemble Model 1, Epoch 15, Batch 20, Loss: 0.056
# Ensemble Model 1, Epoch 16, Batch 10, Loss: 0.053
# Ensemble Model 1, Epoch 16, Batch 20, Loss: 0.055
# Ensemble Model 1, Epoch 17, Batch 10, Loss: 0.041
# Ensemble Model 1, Epoch 17, Batch 20, Loss: 0.068
# Ensemble Model 1, Epoch 18, Batch 10, Loss: 0.065
# Ensemble Model 1, Epoch 18, Batch 20, Loss: 0.040
# Ensemble Model 1, Epoch 19, Batch 10, Loss: 0.046
# Ensemble Model 1, Epoch 19, Batch 20, Loss: 0.059
# Ensemble Model 1, Epoch 20, Batch 10, Loss: 0.053
# Ensemble Model 1, Epoch 20, Batch 20, Loss: 0.055
# Ensemble Model 1, Epoch 21, Batch 10, Loss: 0.062
# Ensemble Model 1, Epoch 21, Batch 20, Loss: 0.041
# Ensemble Model 1, Epoch 22, Batch 10, Loss: 0.051
# Ensemble Model 1, Epoch 22, Batch 20, Loss: 0.053
# Ensemble Model 1, Epoch 23, Batch 10, Loss: 0.053
# Ensemble Model 1, Epoch 23, Batch 20, Loss: 0.052
# Ensemble Model 1, Epoch 24, Batch 10, Loss: 0.055
# Ensemble Model 1, Epoch 24, Batch 20, Loss: 0.051
# Ensemble Model 1, Epoch 25, Batch 10, Loss: 0.053
# Ensemble Model 1, Epoch 25, Batch 20, Loss: 0.049
# Ensemble Model 1, Epoch 26, Batch 10, Loss: 0.054
# Ensemble Model 1, Epoch 26, Batch 20, Loss: 0.049
# Ensemble Model 1, Epoch 27, Batch 10, Loss: 0.057
# Ensemble Model 1, Epoch 27, Batch 20, Loss: 0.047
# Ensemble Model 1, Epoch 28, Batch 10, Loss: 0.048
# Ensemble Model 1, Epoch 28, Batch 20, Loss: 0.056
# Ensemble Model 1, Epoch 29, Batch 10, Loss: 0.059
# Ensemble Model 1, Epoch 29, Batch 20, Loss: 0.044
# Ensemble Model 1, Epoch 30, Batch 10, Loss: 0.041
# Ensemble Model 1, Epoch 30, Batch 20, Loss: 0.063
# Ensemble Model 1, Validation Loss: 0.022
# ***************************************************
# Training Ensemble Model 2 with Learning Rate: 0.004040688732605834
# Ensemble Model 2, Epoch 1, Batch 10, Loss: 0.109
# Ensemble Model 2, Epoch 1, Batch 20, Loss: 0.114
# Ensemble Model 2, Epoch 2, Batch 10, Loss: 0.101
# Ensemble Model 2, Epoch 2, Batch 20, Loss: 0.091
# Ensemble Model 2, Epoch 3, Batch 10, Loss: 0.076
# Ensemble Model 2, Epoch 3, Batch 20, Loss: 0.060
# Ensemble Model 2, Epoch 4, Batch 10, Loss: 0.057
# Ensemble Model 2, Epoch 4, Batch 20, Loss: 0.067
# Ensemble Model 2, Epoch 5, Batch 10, Loss: 0.057
# Ensemble Model 2, Epoch 5, Batch 20, Loss: 0.057
# Ensemble Model 2, Epoch 6, Batch 10, Loss: 0.065
# Ensemble Model 2, Epoch 6, Batch 20, Loss: 0.065
# Ensemble Model 2, Epoch 7, Batch 10, Loss: 0.055
# Ensemble Model 2, Epoch 7, Batch 20, Loss: 0.058
# Ensemble Model 2, Epoch 8, Batch 10, Loss: 0.066
# Ensemble Model 2, Epoch 8, Batch 20, Loss: 0.043
# Ensemble Model 2, Epoch 9, Batch 10, Loss: 0.056
# Ensemble Model 2, Epoch 9, Batch 20, Loss: 0.056
# Ensemble Model 2, Epoch 10, Batch 10, Loss: 0.048
# Ensemble Model 2, Epoch 10, Batch 20, Loss: 0.061
# Ensemble Model 2, Epoch 11, Batch 10, Loss: 0.071
# Ensemble Model 2, Epoch 11, Batch 20, Loss: 0.041
# Ensemble Model 2, Epoch 12, Batch 10, Loss: 0.055
# Ensemble Model 2, Epoch 12, Batch 20, Loss: 0.051
# Ensemble Model 2, Epoch 13, Batch 10, Loss: 0.053
# Ensemble Model 2, Epoch 13, Batch 20, Loss: 0.054
# Ensemble Model 2, Epoch 14, Batch 10, Loss: 0.067
# Ensemble Model 2, Epoch 14, Batch 20, Loss: 0.037
# Ensemble Model 2, Epoch 15, Batch 10, Loss: 0.053
# Ensemble Model 2, Epoch 15, Batch 20, Loss: 0.054
# Ensemble Model 2, Epoch 16, Batch 10, Loss: 0.064
# Ensemble Model 2, Epoch 16, Batch 20, Loss: 0.042
# Ensemble Model 2, Epoch 17, Batch 10, Loss: 0.056
# Ensemble Model 2, Epoch 17, Batch 20, Loss: 0.047
# Ensemble Model 2, Epoch 18, Batch 10, Loss: 0.045
# Ensemble Model 2, Epoch 18, Batch 20, Loss: 0.059
# Ensemble Model 2, Epoch 19, Batch 10, Loss: 0.048
# Ensemble Model 2, Epoch 19, Batch 20, Loss: 0.057
# Ensemble Model 2, Epoch 20, Batch 10, Loss: 0.049
# Ensemble Model 2, Epoch 20, Batch 20, Loss: 0.054
# Ensemble Model 2, Epoch 21, Batch 10, Loss: 0.049
# Ensemble Model 2, Epoch 21, Batch 20, Loss: 0.060
# Ensemble Model 2, Epoch 22, Batch 10, Loss: 0.039
# Ensemble Model 2, Epoch 22, Batch 20, Loss: 0.064
# Ensemble Model 2, Epoch 23, Batch 10, Loss: 0.054
# Ensemble Model 2, Epoch 23, Batch 20, Loss: 0.049
# Ensemble Model 2, Epoch 24, Batch 10, Loss: 0.054
# Ensemble Model 2, Epoch 24, Batch 20, Loss: 0.049
# Ensemble Model 2, Epoch 25, Batch 10, Loss: 0.057
# Ensemble Model 2, Epoch 25, Batch 20, Loss: 0.046
# Ensemble Model 2, Epoch 26, Batch 10, Loss: 0.070
# Ensemble Model 2, Epoch 26, Batch 20, Loss: 0.038
# Ensemble Model 2, Epoch 27, Batch 10, Loss: 0.057
# Ensemble Model 2, Epoch 27, Batch 20, Loss: 0.047
# Ensemble Model 2, Epoch 28, Batch 10, Loss: 0.049
# Ensemble Model 2, Epoch 28, Batch 20, Loss: 0.056
# Ensemble Model 2, Epoch 29, Batch 10, Loss: 0.058
# Ensemble Model 2, Epoch 29, Batch 20, Loss: 0.047
# Ensemble Model 2, Epoch 30, Batch 10, Loss: 0.049
# Ensemble Model 2, Epoch 30, Batch 20, Loss: 0.052
# Ensemble Model 2, Validation Loss: 0.024
# ***************************************************
# Training Ensemble Model 3 with Learning Rate: 0.0013391636963361862
# Ensemble Model 3, Epoch 1, Batch 10, Loss: 0.119
# Ensemble Model 3, Epoch 1, Batch 20, Loss: 0.108
# Ensemble Model 3, Epoch 2, Batch 10, Loss: 0.132
# Ensemble Model 3, Epoch 2, Batch 20, Loss: 0.096
# Ensemble Model 3, Epoch 3, Batch 10, Loss: 0.129
# Ensemble Model 3, Epoch 3, Batch 20, Loss: 0.097
# Ensemble Model 3, Epoch 4, Batch 10, Loss: 0.108
# Ensemble Model 3, Epoch 4, Batch 20, Loss: 0.120
# Ensemble Model 3, Epoch 5, Batch 10, Loss: 0.115
# Ensemble Model 3, Epoch 5, Batch 20, Loss: 0.107
# Ensemble Model 3, Epoch 6, Batch 10, Loss: 0.100
# Ensemble Model 3, Epoch 6, Batch 20, Loss: 0.109
# Ensemble Model 3, Epoch 7, Batch 10, Loss: 0.082
# Ensemble Model 3, Epoch 7, Batch 20, Loss: 0.097
# Ensemble Model 3, Epoch 8, Batch 10, Loss: 0.075
# Ensemble Model 3, Epoch 8, Batch 20, Loss: 0.074
# Ensemble Model 3, Epoch 9, Batch 10, Loss: 0.071
# Ensemble Model 3, Epoch 9, Batch 20, Loss: 0.065
# Ensemble Model 3, Epoch 10, Batch 10, Loss: 0.068
# Ensemble Model 3, Epoch 10, Batch 20, Loss: 0.057
# Ensemble Model 3, Epoch 11, Batch 10, Loss: 0.062
# Ensemble Model 3, Epoch 11, Batch 20, Loss: 0.062
# Ensemble Model 3, Epoch 12, Batch 10, Loss: 0.051
# Ensemble Model 3, Epoch 12, Batch 20, Loss: 0.069
# Ensemble Model 3, Epoch 13, Batch 10, Loss: 0.061
# Ensemble Model 3, Epoch 13, Batch 20, Loss: 0.053
# Ensemble Model 3, Epoch 14, Batch 10, Loss: 0.070
# Ensemble Model 3, Epoch 14, Batch 20, Loss: 0.045
# Ensemble Model 3, Epoch 15, Batch 10, Loss: 0.069
# Ensemble Model 3, Epoch 15, Batch 20, Loss: 0.043
# Ensemble Model 3, Epoch 16, Batch 10, Loss: 0.057
# Ensemble Model 3, Epoch 16, Batch 20, Loss: 0.056
# Ensemble Model 3, Epoch 17, Batch 10, Loss: 0.059
# Ensemble Model 3, Epoch 17, Batch 20, Loss: 0.053
# Ensemble Model 3, Epoch 18, Batch 10, Loss: 0.056
# Ensemble Model 3, Epoch 18, Batch 20, Loss: 0.058
# Ensemble Model 3, Epoch 19, Batch 10, Loss: 0.050
# Ensemble Model 3, Epoch 19, Batch 20, Loss: 0.062
# Ensemble Model 3, Epoch 20, Batch 10, Loss: 0.057
# Ensemble Model 3, Epoch 20, Batch 20, Loss: 0.053
# Ensemble Model 3, Epoch 21, Batch 10, Loss: 0.050
# Ensemble Model 3, Epoch 21, Batch 20, Loss: 0.059
# Ensemble Model 3, Epoch 22, Batch 10, Loss: 0.062
# Ensemble Model 3, Epoch 22, Batch 20, Loss: 0.050
# Ensemble Model 3, Epoch 23, Batch 10, Loss: 0.058
# Ensemble Model 3, Epoch 23, Batch 20, Loss: 0.051
# Ensemble Model 3, Epoch 24, Batch 10, Loss: 0.061
# Ensemble Model 3, Epoch 24, Batch 20, Loss: 0.048
# Ensemble Model 3, Epoch 25, Batch 10, Loss: 0.060
# Ensemble Model 3, Epoch 25, Batch 20, Loss: 0.049
# Ensemble Model 3, Epoch 26, Batch 10, Loss: 0.060
# Ensemble Model 3, Epoch 26, Batch 20, Loss: 0.049
# Ensemble Model 3, Epoch 27, Batch 10, Loss: 0.050
# Ensemble Model 3, Epoch 27, Batch 20, Loss: 0.060
# Ensemble Model 3, Epoch 28, Batch 10, Loss: 0.054
# Ensemble Model 3, Epoch 28, Batch 20, Loss: 0.055
# Ensemble Model 3, Epoch 29, Batch 10, Loss: 0.055
# Ensemble Model 3, Epoch 29, Batch 20, Loss: 0.054
# Ensemble Model 3, Epoch 30, Batch 10, Loss: 0.054
# Ensemble Model 3, Epoch 30, Batch 20, Loss: 0.056
# Ensemble Model 3, Validation Loss: 0.021
# ***************************************************
# Training Ensemble Model 4 with Learning Rate: 0.00026702423828439605
# Ensemble Model 4, Epoch 1, Batch 10, Loss: 0.110
# Ensemble Model 4, Epoch 1, Batch 20, Loss: 0.124
# Ensemble Model 4, Epoch 2, Batch 10, Loss: 0.117
# Ensemble Model 4, Epoch 2, Batch 20, Loss: 0.116
# Ensemble Model 4, Epoch 3, Batch 10, Loss: 0.132
# Ensemble Model 4, Epoch 3, Batch 20, Loss: 0.101
# Ensemble Model 4, Epoch 4, Batch 10, Loss: 0.108
# Ensemble Model 4, Epoch 4, Batch 20, Loss: 0.123
# Ensemble Model 4, Epoch 5, Batch 10, Loss: 0.107
# Ensemble Model 4, Epoch 5, Batch 20, Loss: 0.126
# Ensemble Model 4, Epoch 6, Batch 10, Loss: 0.096
# Ensemble Model 4, Epoch 6, Batch 20, Loss: 0.133
# Ensemble Model 4, Epoch 7, Batch 10, Loss: 0.118
# Ensemble Model 4, Epoch 7, Batch 20, Loss: 0.113
# Ensemble Model 4, Epoch 8, Batch 10, Loss: 0.122
# Ensemble Model 4, Epoch 8, Batch 20, Loss: 0.105
# Ensemble Model 4, Epoch 9, Batch 10, Loss: 0.110
# Ensemble Model 4, Epoch 9, Batch 20, Loss: 0.116
# Ensemble Model 4, Epoch 10, Batch 10, Loss: 0.116
# Ensemble Model 4, Epoch 10, Batch 20, Loss: 0.107
# Ensemble Model 4, Epoch 11, Batch 10, Loss: 0.107
# Ensemble Model 4, Epoch 11, Batch 20, Loss: 0.123
# Ensemble Model 4, Epoch 12, Batch 10, Loss: 0.106
# Ensemble Model 4, Epoch 12, Batch 20, Loss: 0.118
# Ensemble Model 4, Epoch 13, Batch 10, Loss: 0.111
# Ensemble Model 4, Epoch 13, Batch 20, Loss: 0.112
# Ensemble Model 4, Epoch 14, Batch 10, Loss: 0.103
# Ensemble Model 4, Epoch 14, Batch 20, Loss: 0.122
# Ensemble Model 4, Epoch 15, Batch 10, Loss: 0.101
# Ensemble Model 4, Epoch 15, Batch 20, Loss: 0.118
# Ensemble Model 4, Epoch 16, Batch 10, Loss: 0.113
# Ensemble Model 4, Epoch 16, Batch 20, Loss: 0.107
# Ensemble Model 4, Epoch 17, Batch 10, Loss: 0.127
# Ensemble Model 4, Epoch 17, Batch 20, Loss: 0.093
# Ensemble Model 4, Epoch 18, Batch 10, Loss: 0.095
# Ensemble Model 4, Epoch 18, Batch 20, Loss: 0.119
# Ensemble Model 4, Epoch 19, Batch 10, Loss: 0.094
# Ensemble Model 4, Epoch 19, Batch 20, Loss: 0.128
# Ensemble Model 4, Epoch 20, Batch 10, Loss: 0.121
# Ensemble Model 4, Epoch 20, Batch 20, Loss: 0.091
# Ensemble Model 4, Epoch 21, Batch 10, Loss: 0.113
# Ensemble Model 4, Epoch 21, Batch 20, Loss: 0.106
# Ensemble Model 4, Epoch 22, Batch 10, Loss: 0.104
# Ensemble Model 4, Epoch 22, Batch 20, Loss: 0.105
# Ensemble Model 4, Epoch 23, Batch 10, Loss: 0.089
# Ensemble Model 4, Epoch 23, Batch 20, Loss: 0.124
# Ensemble Model 4, Epoch 24, Batch 10, Loss: 0.107
# Ensemble Model 4, Epoch 24, Batch 20, Loss: 0.100
# Ensemble Model 4, Epoch 25, Batch 10, Loss: 0.103
# Ensemble Model 4, Epoch 25, Batch 20, Loss: 0.102
# Ensemble Model 4, Epoch 26, Batch 10, Loss: 0.098
# Ensemble Model 4, Epoch 26, Batch 20, Loss: 0.109
# Ensemble Model 4, Epoch 27, Batch 10, Loss: 0.105
# Ensemble Model 4, Epoch 27, Batch 20, Loss: 0.096
# Ensemble Model 4, Epoch 28, Batch 10, Loss: 0.100
# Ensemble Model 4, Epoch 28, Batch 20, Loss: 0.094
# Ensemble Model 4, Epoch 29, Batch 10, Loss: 0.112
# Ensemble Model 4, Epoch 29, Batch 20, Loss: 0.079
# Ensemble Model 4, Epoch 30, Batch 10, Loss: 0.097
# Ensemble Model 4, Epoch 30, Batch 20, Loss: 0.092
# Ensemble Model 4, Validation Loss: 0.023
# ***************************************************
# Training Ensemble Model 5 with Learning Rate: 0.0001774192654457743
# Ensemble Model 5, Epoch 1, Batch 10, Loss: 0.119
# Ensemble Model 5, Epoch 1, Batch 20, Loss: 0.113
# Ensemble Model 5, Epoch 2, Batch 10, Loss: 0.114
# Ensemble Model 5, Epoch 2, Batch 20, Loss: 0.119
# Ensemble Model 5, Epoch 3, Batch 10, Loss: 0.103
# Ensemble Model 5, Epoch 3, Batch 20, Loss: 0.128
# Ensemble Model 5, Epoch 4, Batch 10, Loss: 0.124
# Ensemble Model 5, Epoch 4, Batch 20, Loss: 0.108
# Ensemble Model 5, Epoch 5, Batch 10, Loss: 0.140
# Ensemble Model 5, Epoch 5, Batch 20, Loss: 0.090
# Ensemble Model 5, Epoch 6, Batch 10, Loss: 0.107
# Ensemble Model 5, Epoch 6, Batch 20, Loss: 0.119
# Ensemble Model 5, Epoch 7, Batch 10, Loss: 0.107
# Ensemble Model 5, Epoch 7, Batch 20, Loss: 0.121
# Ensemble Model 5, Epoch 8, Batch 10, Loss: 0.122
# Ensemble Model 5, Epoch 8, Batch 20, Loss: 0.102
# Ensemble Model 5, Epoch 9, Batch 10, Loss: 0.099
# Ensemble Model 5, Epoch 9, Batch 20, Loss: 0.125
# Ensemble Model 5, Epoch 10, Batch 10, Loss: 0.108
# Ensemble Model 5, Epoch 10, Batch 20, Loss: 0.116
# Ensemble Model 5, Epoch 11, Batch 10, Loss: 0.099
# Ensemble Model 5, Epoch 11, Batch 20, Loss: 0.122
# Ensemble Model 5, Epoch 12, Batch 10, Loss: 0.119
# Ensemble Model 5, Epoch 12, Batch 20, Loss: 0.104
# Ensemble Model 5, Epoch 13, Batch 10, Loss: 0.108
# Ensemble Model 5, Epoch 13, Batch 20, Loss: 0.110
# Ensemble Model 5, Epoch 14, Batch 10, Loss: 0.109
# Ensemble Model 5, Epoch 14, Batch 20, Loss: 0.114
# Ensemble Model 5, Epoch 15, Batch 10, Loss: 0.107
# Ensemble Model 5, Epoch 15, Batch 20, Loss: 0.111
# Ensemble Model 5, Epoch 16, Batch 10, Loss: 0.089
# Ensemble Model 5, Epoch 16, Batch 20, Loss: 0.130
# Ensemble Model 5, Epoch 17, Batch 10, Loss: 0.109
# Ensemble Model 5, Epoch 17, Batch 20, Loss: 0.104
# Ensemble Model 5, Epoch 18, Batch 10, Loss: 0.113
# Ensemble Model 5, Epoch 18, Batch 20, Loss: 0.103
# Ensemble Model 5, Epoch 19, Batch 10, Loss: 0.084
# Ensemble Model 5, Epoch 19, Batch 20, Loss: 0.126
# Ensemble Model 5, Epoch 20, Batch 10, Loss: 0.115
# Ensemble Model 5, Epoch 20, Batch 20, Loss: 0.092
# Ensemble Model 5, Epoch 21, Batch 10, Loss: 0.104
# Ensemble Model 5, Epoch 21, Batch 20, Loss: 0.102
# Ensemble Model 5, Epoch 22, Batch 10, Loss: 0.103
# Ensemble Model 5, Epoch 22, Batch 20, Loss: 0.095
# Ensemble Model 5, Epoch 23, Batch 10, Loss: 0.110
# Ensemble Model 5, Epoch 23, Batch 20, Loss: 0.087
# Ensemble Model 5, Epoch 24, Batch 10, Loss: 0.086
# Ensemble Model 5, Epoch 24, Batch 20, Loss: 0.104
# Ensemble Model 5, Epoch 25, Batch 10, Loss: 0.093
# Ensemble Model 5, Epoch 25, Batch 20, Loss: 0.096
# Ensemble Model 5, Epoch 26, Batch 10, Loss: 0.085
# Ensemble Model 5, Epoch 26, Batch 20, Loss: 0.091
# Ensemble Model 5, Epoch 27, Batch 10, Loss: 0.077
# Ensemble Model 5, Epoch 27, Batch 20, Loss: 0.094
# Ensemble Model 5, Epoch 28, Batch 10, Loss: 0.083
# Ensemble Model 5, Epoch 28, Batch 20, Loss: 0.081
# Ensemble Model 5, Epoch 29, Batch 10, Loss: 0.094
# Ensemble Model 5, Epoch 29, Batch 20, Loss: 0.062
# Ensemble Model 5, Epoch 30, Batch 10, Loss: 0.082
# Ensemble Model 5, Epoch 30, Batch 20, Loss: 0.063
# Ensemble Model 5, Validation Loss: 0.021
# ***************************************************
# Training Ensemble Model 6 with Learning Rate: 0.004705995096847897
# Ensemble Model 6, Epoch 1, Batch 10, Loss: 0.108
# Ensemble Model 6, Epoch 1, Batch 20, Loss: 0.116
# Ensemble Model 6, Epoch 2, Batch 10, Loss: 0.125
# Ensemble Model 6, Epoch 2, Batch 20, Loss: 0.095
# Ensemble Model 6, Epoch 3, Batch 10, Loss: 0.079
# Ensemble Model 6, Epoch 3, Batch 20, Loss: 0.067
# Ensemble Model 6, Epoch 4, Batch 10, Loss: 0.070
# Ensemble Model 6, Epoch 4, Batch 20, Loss: 0.050
# Ensemble Model 6, Epoch 5, Batch 10, Loss: 0.058
# Ensemble Model 6, Epoch 5, Batch 20, Loss: 0.056
# Ensemble Model 6, Epoch 6, Batch 10, Loss: 0.050
# Ensemble Model 6, Epoch 6, Batch 20, Loss: 0.070
# Ensemble Model 6, Epoch 7, Batch 10, Loss: 0.065
# Ensemble Model 6, Epoch 7, Batch 20, Loss: 0.047
# Ensemble Model 6, Epoch 8, Batch 10, Loss: 0.051
# Ensemble Model 6, Epoch 8, Batch 20, Loss: 0.061
# Ensemble Model 6, Epoch 9, Batch 10, Loss: 0.055
# Ensemble Model 6, Epoch 9, Batch 20, Loss: 0.055
# Ensemble Model 6, Epoch 10, Batch 10, Loss: 0.051
# Ensemble Model 6, Epoch 10, Batch 20, Loss: 0.062
# Ensemble Model 6, Epoch 11, Batch 10, Loss: 0.060
# Ensemble Model 6, Epoch 11, Batch 20, Loss: 0.049
# Ensemble Model 6, Epoch 12, Batch 10, Loss: 0.059
# Ensemble Model 6, Epoch 12, Batch 20, Loss: 0.048
# Ensemble Model 6, Epoch 13, Batch 10, Loss: 0.045
# Ensemble Model 6, Epoch 13, Batch 20, Loss: 0.063
# Ensemble Model 6, Epoch 14, Batch 10, Loss: 0.045
# Ensemble Model 6, Epoch 14, Batch 20, Loss: 0.063
# Ensemble Model 6, Epoch 15, Batch 10, Loss: 0.059
# Ensemble Model 6, Epoch 15, Batch 20, Loss: 0.049
# Ensemble Model 6, Epoch 16, Batch 10, Loss: 0.061
# Ensemble Model 6, Epoch 16, Batch 20, Loss: 0.047
# Ensemble Model 6, Epoch 17, Batch 10, Loss: 0.061
# Ensemble Model 6, Epoch 17, Batch 20, Loss: 0.053
# Ensemble Model 6, Epoch 18, Batch 10, Loss: 0.046
# Ensemble Model 6, Epoch 18, Batch 20, Loss: 0.059
# Ensemble Model 6, Epoch 19, Batch 10, Loss: 0.056
# Ensemble Model 6, Epoch 19, Batch 20, Loss: 0.049
# Ensemble Model 6, Epoch 20, Batch 10, Loss: 0.045
# Ensemble Model 6, Epoch 20, Batch 20, Loss: 0.060
# Ensemble Model 6, Epoch 21, Batch 10, Loss: 0.061
# Ensemble Model 6, Epoch 21, Batch 20, Loss: 0.044
# Ensemble Model 6, Epoch 22, Batch 10, Loss: 0.060
# Ensemble Model 6, Epoch 22, Batch 20, Loss: 0.049
# Ensemble Model 6, Epoch 23, Batch 10, Loss: 0.051
# Ensemble Model 6, Epoch 23, Batch 20, Loss: 0.056
# Ensemble Model 6, Epoch 24, Batch 10, Loss: 0.051
# Ensemble Model 6, Epoch 24, Batch 20, Loss: 0.055
# Ensemble Model 6, Epoch 25, Batch 10, Loss: 0.045
# Ensemble Model 6, Epoch 25, Batch 20, Loss: 0.059
# Ensemble Model 6, Epoch 26, Batch 10, Loss: 0.047
# Ensemble Model 6, Epoch 26, Batch 20, Loss: 0.057
# Ensemble Model 6, Epoch 27, Batch 10, Loss: 0.049
# Ensemble Model 6, Epoch 27, Batch 20, Loss: 0.055
# Ensemble Model 6, Epoch 28, Batch 10, Loss: 0.054
# Ensemble Model 6, Epoch 28, Batch 20, Loss: 0.059
# Ensemble Model 6, Epoch 29, Batch 10, Loss: 0.049
# Ensemble Model 6, Epoch 29, Batch 20, Loss: 0.052
# Ensemble Model 6, Epoch 30, Batch 10, Loss: 0.054
# Ensemble Model 6, Epoch 30, Batch 20, Loss: 0.050
# Ensemble Model 6, Validation Loss: 0.022
# ***************************************************
# Training Ensemble Model 7 with Learning Rate: 0.002342258149263695
# Ensemble Model 7, Epoch 1, Batch 10, Loss: 0.114
# Ensemble Model 7, Epoch 1, Batch 20, Loss: 0.123
# Ensemble Model 7, Epoch 2, Batch 10, Loss: 0.117
# Ensemble Model 7, Epoch 2, Batch 20, Loss: 0.113
# Ensemble Model 7, Epoch 3, Batch 10, Loss: 0.103
# Ensemble Model 7, Epoch 3, Batch 20, Loss: 0.117
# Ensemble Model 7, Epoch 4, Batch 10, Loss: 0.096
# Ensemble Model 7, Epoch 4, Batch 20, Loss: 0.085
# Ensemble Model 7, Epoch 5, Batch 10, Loss: 0.069
# Ensemble Model 7, Epoch 5, Batch 20, Loss: 0.072
# Ensemble Model 7, Epoch 6, Batch 10, Loss: 0.081
# Ensemble Model 7, Epoch 6, Batch 20, Loss: 0.051
# Ensemble Model 7, Epoch 7, Batch 10, Loss: 0.071
# Ensemble Model 7, Epoch 7, Batch 20, Loss: 0.053
# Ensemble Model 7, Epoch 8, Batch 10, Loss: 0.054
# Ensemble Model 7, Epoch 8, Batch 20, Loss: 0.069
# Ensemble Model 7, Epoch 9, Batch 10, Loss: 0.070
# Ensemble Model 7, Epoch 9, Batch 20, Loss: 0.051
# Ensemble Model 7, Epoch 10, Batch 10, Loss: 0.060
# Ensemble Model 7, Epoch 10, Batch 20, Loss: 0.058
# Ensemble Model 7, Epoch 11, Batch 10, Loss: 0.058
# Ensemble Model 7, Epoch 11, Batch 20, Loss: 0.058
# Ensemble Model 7, Epoch 12, Batch 10, Loss: 0.049
# Ensemble Model 7, Epoch 12, Batch 20, Loss: 0.067
# Ensemble Model 7, Epoch 13, Batch 10, Loss: 0.050
# Ensemble Model 7, Epoch 13, Batch 20, Loss: 0.067
# Ensemble Model 7, Epoch 14, Batch 10, Loss: 0.051
# Ensemble Model 7, Epoch 14, Batch 20, Loss: 0.065
# Ensemble Model 7, Epoch 15, Batch 10, Loss: 0.055
# Ensemble Model 7, Epoch 15, Batch 20, Loss: 0.060
# Ensemble Model 7, Epoch 16, Batch 10, Loss: 0.044
# Ensemble Model 7, Epoch 16, Batch 20, Loss: 0.068
# Ensemble Model 7, Epoch 17, Batch 10, Loss: 0.040
# Ensemble Model 7, Epoch 17, Batch 20, Loss: 0.072
# Ensemble Model 7, Epoch 18, Batch 10, Loss: 0.063
# Ensemble Model 7, Epoch 18, Batch 20, Loss: 0.047
# Ensemble Model 7, Epoch 19, Batch 10, Loss: 0.061
# Ensemble Model 7, Epoch 19, Batch 20, Loss: 0.048
# Ensemble Model 7, Epoch 20, Batch 10, Loss: 0.065
# Ensemble Model 7, Epoch 20, Batch 20, Loss: 0.044
# Ensemble Model 7, Epoch 21, Batch 10, Loss: 0.061
# Ensemble Model 7, Epoch 21, Batch 20, Loss: 0.049
# Ensemble Model 7, Epoch 22, Batch 10, Loss: 0.062
# Ensemble Model 7, Epoch 22, Batch 20, Loss: 0.045
# Ensemble Model 7, Epoch 23, Batch 10, Loss: 0.049
# Ensemble Model 7, Epoch 23, Batch 20, Loss: 0.058
# Ensemble Model 7, Epoch 24, Batch 10, Loss: 0.047
# Ensemble Model 7, Epoch 24, Batch 20, Loss: 0.058
# Ensemble Model 7, Epoch 25, Batch 10, Loss: 0.058
# Ensemble Model 7, Epoch 25, Batch 20, Loss: 0.051
# Ensemble Model 7, Epoch 26, Batch 10, Loss: 0.053
# Ensemble Model 7, Epoch 26, Batch 20, Loss: 0.053
# Ensemble Model 7, Epoch 27, Batch 10, Loss: 0.044
# Ensemble Model 7, Epoch 27, Batch 20, Loss: 0.065
# Ensemble Model 7, Epoch 28, Batch 10, Loss: 0.045
# Ensemble Model 7, Epoch 28, Batch 20, Loss: 0.069
# Ensemble Model 7, Epoch 29, Batch 10, Loss: 0.063
# Ensemble Model 7, Epoch 29, Batch 20, Loss: 0.039
# Ensemble Model 7, Epoch 30, Batch 10, Loss: 0.056
# Ensemble Model 7, Epoch 30, Batch 20, Loss: 0.047
# Ensemble Model 7, Validation Loss: 0.022
# ***************************************************
# Training Ensemble Model 8 with Learning Rate: 0.004629626716572193
# Ensemble Model 8, Epoch 1, Batch 10, Loss: 0.114
# Ensemble Model 8, Epoch 1, Batch 20, Loss: 0.110
# Ensemble Model 8, Epoch 2, Batch 10, Loss: 0.106
# Ensemble Model 8, Epoch 2, Batch 20, Loss: 0.122
# Ensemble Model 8, Epoch 3, Batch 10, Loss: 0.110
# Ensemble Model 8, Epoch 3, Batch 20, Loss: 0.105
# Ensemble Model 8, Epoch 4, Batch 10, Loss: 0.086
# Ensemble Model 8, Epoch 4, Batch 20, Loss: 0.067
# Ensemble Model 8, Epoch 5, Batch 10, Loss: 0.065
# Ensemble Model 8, Epoch 5, Batch 20, Loss: 0.059
# Ensemble Model 8, Epoch 6, Batch 10, Loss: 0.054
# Ensemble Model 8, Epoch 6, Batch 20, Loss: 0.063
# Ensemble Model 8, Epoch 7, Batch 10, Loss: 0.044
# Ensemble Model 8, Epoch 7, Batch 20, Loss: 0.074
# Ensemble Model 8, Epoch 8, Batch 10, Loss: 0.053
# Ensemble Model 8, Epoch 8, Batch 20, Loss: 0.058
# Ensemble Model 8, Epoch 9, Batch 10, Loss: 0.069
# Ensemble Model 8, Epoch 9, Batch 20, Loss: 0.040
# Ensemble Model 8, Epoch 10, Batch 10, Loss: 0.055
# Ensemble Model 8, Epoch 10, Batch 20, Loss: 0.052
# Ensemble Model 8, Epoch 11, Batch 10, Loss: 0.048
# Ensemble Model 8, Epoch 11, Batch 20, Loss: 0.059
# Ensemble Model 8, Epoch 12, Batch 10, Loss: 0.053
# Ensemble Model 8, Epoch 12, Batch 20, Loss: 0.054
# Ensemble Model 8, Epoch 13, Batch 10, Loss: 0.054
# Ensemble Model 8, Epoch 13, Batch 20, Loss: 0.055
# Ensemble Model 8, Epoch 14, Batch 10, Loss: 0.059
# Ensemble Model 8, Epoch 14, Batch 20, Loss: 0.052
# Ensemble Model 8, Epoch 15, Batch 10, Loss: 0.042
# Ensemble Model 8, Epoch 15, Batch 20, Loss: 0.065
# Ensemble Model 8, Epoch 16, Batch 10, Loss: 0.053
# Ensemble Model 8, Epoch 16, Batch 20, Loss: 0.050
# Ensemble Model 8, Epoch 17, Batch 10, Loss: 0.045
# Ensemble Model 8, Epoch 17, Batch 20, Loss: 0.061
# Ensemble Model 8, Epoch 18, Batch 10, Loss: 0.044
# Ensemble Model 8, Epoch 18, Batch 20, Loss: 0.060
# Ensemble Model 8, Epoch 19, Batch 10, Loss: 0.053
# Ensemble Model 8, Epoch 19, Batch 20, Loss: 0.054
# Ensemble Model 8, Epoch 20, Batch 10, Loss: 0.062
# Ensemble Model 8, Epoch 20, Batch 20, Loss: 0.042
# Ensemble Model 8, Epoch 21, Batch 10, Loss: 0.053
# Ensemble Model 8, Epoch 21, Batch 20, Loss: 0.054
# Ensemble Model 8, Epoch 22, Batch 10, Loss: 0.048
# Ensemble Model 8, Epoch 22, Batch 20, Loss: 0.054
# Ensemble Model 8, Epoch 23, Batch 10, Loss: 0.053
# Ensemble Model 8, Epoch 23, Batch 20, Loss: 0.051
# Ensemble Model 8, Epoch 24, Batch 10, Loss: 0.047
# Ensemble Model 8, Epoch 24, Batch 20, Loss: 0.056
# Ensemble Model 8, Epoch 25, Batch 10, Loss: 0.057
# Ensemble Model 8, Epoch 25, Batch 20, Loss: 0.045
# Ensemble Model 8, Epoch 26, Batch 10, Loss: 0.048
# Ensemble Model 8, Epoch 26, Batch 20, Loss: 0.058
# Ensemble Model 8, Epoch 27, Batch 10, Loss: 0.061
# Ensemble Model 8, Epoch 27, Batch 20, Loss: 0.041
# Ensemble Model 8, Epoch 28, Batch 10, Loss: 0.059
# Ensemble Model 8, Epoch 28, Batch 20, Loss: 0.046
# Ensemble Model 8, Epoch 29, Batch 10, Loss: 0.049
# Ensemble Model 8, Epoch 29, Batch 20, Loss: 0.056
# Ensemble Model 8, Epoch 30, Batch 10, Loss: 0.062
# Ensemble Model 8, Epoch 30, Batch 20, Loss: 0.040
# Ensemble Model 8, Validation Loss: 0.023
# ***************************************************
# Training Ensemble Model 9 with Learning Rate: 0.001757047455919879
# Ensemble Model 9, Epoch 1, Batch 10, Loss: 0.134
# Ensemble Model 9, Epoch 1, Batch 20, Loss: 0.107
# Ensemble Model 9, Epoch 2, Batch 10, Loss: 0.105
# Ensemble Model 9, Epoch 2, Batch 20, Loss: 0.101
# Ensemble Model 9, Epoch 3, Batch 10, Loss: 0.101
# Ensemble Model 9, Epoch 3, Batch 20, Loss: 0.076
# Ensemble Model 9, Epoch 4, Batch 10, Loss: 0.079
# Ensemble Model 9, Epoch 4, Batch 20, Loss: 0.066
# Ensemble Model 9, Epoch 5, Batch 10, Loss: 0.062
# Ensemble Model 9, Epoch 5, Batch 20, Loss: 0.058
# Ensemble Model 9, Epoch 6, Batch 10, Loss: 0.060
# Ensemble Model 9, Epoch 6, Batch 20, Loss: 0.057
# Ensemble Model 9, Epoch 7, Batch 10, Loss: 0.054
# Ensemble Model 9, Epoch 7, Batch 20, Loss: 0.055
# Ensemble Model 9, Epoch 8, Batch 10, Loss: 0.066
# Ensemble Model 9, Epoch 8, Batch 20, Loss: 0.045
# Ensemble Model 9, Epoch 9, Batch 10, Loss: 0.069
# Ensemble Model 9, Epoch 9, Batch 20, Loss: 0.040
# Ensemble Model 9, Epoch 10, Batch 10, Loss: 0.061
# Ensemble Model 9, Epoch 10, Batch 20, Loss: 0.046
# Ensemble Model 9, Epoch 11, Batch 10, Loss: 0.058
# Ensemble Model 9, Epoch 11, Batch 20, Loss: 0.051
# Ensemble Model 9, Epoch 12, Batch 10, Loss: 0.053
# Ensemble Model 9, Epoch 12, Batch 20, Loss: 0.053
# Ensemble Model 9, Epoch 13, Batch 10, Loss: 0.066
# Ensemble Model 9, Epoch 13, Batch 20, Loss: 0.039
# Ensemble Model 9, Epoch 14, Batch 10, Loss: 0.062
# Ensemble Model 9, Epoch 14, Batch 20, Loss: 0.047
# Ensemble Model 9, Epoch 15, Batch 10, Loss: 0.049
# Ensemble Model 9, Epoch 15, Batch 20, Loss: 0.056
# Ensemble Model 9, Epoch 16, Batch 10, Loss: 0.052
# Ensemble Model 9, Epoch 16, Batch 20, Loss: 0.052
# Ensemble Model 9, Epoch 17, Batch 10, Loss: 0.049
# Ensemble Model 9, Epoch 17, Batch 20, Loss: 0.057
# Ensemble Model 9, Epoch 18, Batch 10, Loss: 0.056
# Ensemble Model 9, Epoch 18, Batch 20, Loss: 0.049
# Ensemble Model 9, Epoch 19, Batch 10, Loss: 0.057
# Ensemble Model 9, Epoch 19, Batch 20, Loss: 0.050
# Ensemble Model 9, Epoch 20, Batch 10, Loss: 0.053
# Ensemble Model 9, Epoch 20, Batch 20, Loss: 0.055
# Ensemble Model 9, Epoch 21, Batch 10, Loss: 0.050
# Ensemble Model 9, Epoch 21, Batch 20, Loss: 0.055
# Ensemble Model 9, Epoch 22, Batch 10, Loss: 0.057
# Ensemble Model 9, Epoch 22, Batch 20, Loss: 0.047
# Ensemble Model 9, Epoch 23, Batch 10, Loss: 0.048
# Ensemble Model 9, Epoch 23, Batch 20, Loss: 0.056
# Ensemble Model 9, Epoch 24, Batch 10, Loss: 0.063
# Ensemble Model 9, Epoch 24, Batch 20, Loss: 0.045
# Ensemble Model 9, Epoch 25, Batch 10, Loss: 0.062
# Ensemble Model 9, Epoch 25, Batch 20, Loss: 0.042
# Ensemble Model 9, Epoch 26, Batch 10, Loss: 0.046
# Ensemble Model 9, Epoch 26, Batch 20, Loss: 0.059
# Ensemble Model 9, Epoch 27, Batch 10, Loss: 0.055
# Ensemble Model 9, Epoch 27, Batch 20, Loss: 0.050
# Ensemble Model 9, Epoch 28, Batch 10, Loss: 0.043
# Ensemble Model 9, Epoch 28, Batch 20, Loss: 0.062
# Ensemble Model 9, Epoch 29, Batch 10, Loss: 0.049
# Ensemble Model 9, Epoch 29, Batch 20, Loss: 0.056
# Ensemble Model 9, Epoch 30, Batch 10, Loss: 0.050
# Ensemble Model 9, Epoch 30, Batch 20, Loss: 0.054
# Ensemble Model 9, Validation Loss: 0.021
# ***************************************************
# Training Ensemble Model 10 with Learning Rate: 0.0026323668839755713
# Ensemble Model 10, Epoch 1, Batch 10, Loss: 0.123
# Ensemble Model 10, Epoch 1, Batch 20, Loss: 0.131
# Ensemble Model 10, Epoch 2, Batch 10, Loss: 0.102
# Ensemble Model 10, Epoch 2, Batch 20, Loss: 0.118
# Ensemble Model 10, Epoch 3, Batch 10, Loss: 0.098
# Ensemble Model 10, Epoch 3, Batch 20, Loss: 0.079
# Ensemble Model 10, Epoch 4, Batch 10, Loss: 0.076
# Ensemble Model 10, Epoch 4, Batch 20, Loss: 0.069
# Ensemble Model 10, Epoch 5, Batch 10, Loss: 0.064
# Ensemble Model 10, Epoch 5, Batch 20, Loss: 0.063
# Ensemble Model 10, Epoch 6, Batch 10, Loss: 0.062
# Ensemble Model 10, Epoch 6, Batch 20, Loss: 0.059
# Ensemble Model 10, Epoch 7, Batch 10, Loss: 0.066
# Ensemble Model 10, Epoch 7, Batch 20, Loss: 0.050
# Ensemble Model 10, Epoch 8, Batch 10, Loss: 0.063
# Ensemble Model 10, Epoch 8, Batch 20, Loss: 0.051
# Ensemble Model 10, Epoch 9, Batch 10, Loss: 0.056
# Ensemble Model 10, Epoch 9, Batch 20, Loss: 0.062
# Ensemble Model 10, Epoch 10, Batch 10, Loss: 0.062
# Ensemble Model 10, Epoch 10, Batch 20, Loss: 0.055
# Ensemble Model 10, Epoch 11, Batch 10, Loss: 0.056
# Ensemble Model 10, Epoch 11, Batch 20, Loss: 0.059
# Ensemble Model 10, Epoch 12, Batch 10, Loss: 0.049
# Ensemble Model 10, Epoch 12, Batch 20, Loss: 0.063
# Ensemble Model 10, Epoch 13, Batch 10, Loss: 0.065
# Ensemble Model 10, Epoch 13, Batch 20, Loss: 0.047
# Ensemble Model 10, Epoch 14, Batch 10, Loss: 0.045
# Ensemble Model 10, Epoch 14, Batch 20, Loss: 0.071
# Ensemble Model 10, Epoch 15, Batch 10, Loss: 0.054
# Ensemble Model 10, Epoch 15, Batch 20, Loss: 0.056
# Ensemble Model 10, Epoch 16, Batch 10, Loss: 0.047
# Ensemble Model 10, Epoch 16, Batch 20, Loss: 0.060
# Ensemble Model 10, Epoch 17, Batch 10, Loss: 0.051
# Ensemble Model 10, Epoch 17, Batch 20, Loss: 0.058
# Ensemble Model 10, Epoch 18, Batch 10, Loss: 0.050
# Ensemble Model 10, Epoch 18, Batch 20, Loss: 0.057
# Ensemble Model 10, Epoch 19, Batch 10, Loss: 0.045
# Ensemble Model 10, Epoch 19, Batch 20, Loss: 0.061
# Ensemble Model 10, Epoch 20, Batch 10, Loss: 0.060
# Ensemble Model 10, Epoch 20, Batch 20, Loss: 0.045
# Ensemble Model 10, Epoch 21, Batch 10, Loss: 0.063
# Ensemble Model 10, Epoch 21, Batch 20, Loss: 0.045
# Ensemble Model 10, Epoch 22, Batch 10, Loss: 0.055
# Ensemble Model 10, Epoch 22, Batch 20, Loss: 0.051
# Ensemble Model 10, Epoch 23, Batch 10, Loss: 0.050
# Ensemble Model 10, Epoch 23, Batch 20, Loss: 0.058
# Ensemble Model 10, Epoch 24, Batch 10, Loss: 0.051
# Ensemble Model 10, Epoch 24, Batch 20, Loss: 0.055
# Ensemble Model 10, Epoch 25, Batch 10, Loss: 0.053
# Ensemble Model 10, Epoch 25, Batch 20, Loss: 0.048
# Ensemble Model 10, Epoch 26, Batch 10, Loss: 0.054
# Ensemble Model 10, Epoch 26, Batch 20, Loss: 0.049
# Ensemble Model 10, Epoch 27, Batch 10, Loss: 0.046
# Ensemble Model 10, Epoch 27, Batch 20, Loss: 0.067
# Ensemble Model 10, Epoch 28, Batch 10, Loss: 0.055
# Ensemble Model 10, Epoch 28, Batch 20, Loss: 0.052
# Ensemble Model 10, Epoch 29, Batch 10, Loss: 0.055
# Ensemble Model 10, Epoch 29, Batch 20, Loss: 0.047
# Ensemble Model 10, Epoch 30, Batch 10, Loss: 0.056
# Ensemble Model 10, Epoch 30, Batch 20, Loss: 0.048
# Ensemble Model 10, Validation Loss: 0.023
# ***************************************************

# %%
# Generate predictions for all models on the training data
all_predictions = []

for model, _ in models:
    with torch.no_grad():
        predicted = model(X_train.to(device)).to('cpu').numpy()
        all_predictions.append(predicted)

# Plot the actual moves and forecasted moves for all models
plt.figure(figsize=(12, 8))
plt.plot(y_train, label='Moves', color='#6699ff')

for i, predicted in enumerate(all_predictions):
    plt.plot(predicted, label=f'Model {i + 1} Forecasted', linestyle='dashed')

plt.xlabel('Week')
plt.ylabel('Moves Over Time')
plt.legend()
plt.show()

# %%
# Visualize individual model predictions on training data
plt.figure(figsize=(12, 8))

for model_idx, (model, _) in enumerate(models):
    with torch.no_grad():
        model.to(device)
        model_predictions = model(X_train.to(device)).detach().cpu().numpy().flatten()

    dummies = np.zeros((X_train.shape[0], lookback + 1))
    dummies[:, 0] = model_predictions
    dummies = scaler.inverse_transform(dummies)

    train_predictions = dc(dummies[:, 0])

    plt.plot(train_predictions, label=f'Model {model_idx + 1}', alpha=0.7)

# Inverse transform the actual values
dummies = np.zeros((X_train.shape[0], lookback + 1))
dummies[:, 0] = y_train.flatten()
dummies = scaler.inverse_transform(dummies)
new_y_train = dc(dummies[:, 0])

plt.plot(new_y_train, label='Actual Moves', color='#6699ff', linewidth=2)
plt.xlabel('Week')
plt.ylabel('Moves Over Time')
plt.title("Individual Model Predictions on Training Data")
plt.legend()
plt.show()

# Visualize individual model predictions on testing data
plt.figure(figsize=(12, 6))

for model_idx, (model, _) in enumerate(models):
    with torch.no_grad():
        model.to(device)
        model_predictions = model(X_test.to(device)).detach().cpu().numpy().flatten()

    dummies = np.zeros((X_test.shape[0], lookback + 1))
    dummies[:, 0] = model_predictions
    dummies = scaler.inverse_transform(dummies)

    test_predictions = dc(dummies[:, 0])

    plt.plot(test_predictions, label=f'Model {model_idx + 1}', alpha=0.7)

# Inverse transform the actual values
dummies = np.zeros((X_test.shape[0], lookback + 1))
dummies[:, 0] = y_test.flatten()
dummies = scaler.inverse_transform(dummies)
new_y_test = dc(dummies[:, 0])

plt.plot(new_y_test, label='Actual Moves', color='#6699ff', linewidth=2)
plt.xlabel('Week')
plt.ylabel('Moves Over Time')
plt.title("Individual Model Predictions on Testing Data")
plt.legend()
plt.show()

# %%
# Combine predictions using weighted average
ensemble_weights = np.ones(num_models) / num_models  # Equal weights for simplicity, you can adjust this based on performance, for example, inverse of validation loss

ensemble_predictions = np.zeros_like(y_test, dtype=float)

for model_idx, (model, _) in enumerate(models):
    with torch.no_grad():
        model.to(device)
        model_predictions = model(X_test.to(device)).detach().cpu().numpy().flatten()

    dummies = np.zeros((X_test.shape[0], lookback + 1))
    dummies[:, 0] = model_predictions
    dummies = scaler.inverse_transform(dummies)

    ensemble_predictions += ensemble_weights[model_idx] * dummies[:, 0] if len(dummies.shape) == 1 else ensemble_weights[model_idx] * dummies[:, 0][:, None]

# Inverse transform the actual values
dummies = np.zeros((X_test.shape[0], lookback + 1))
dummies[:, 0] = y_test.flatten()
dummies = scaler.inverse_transform(dummies)
new_y_test = dc(dummies[:, 0])

# Visualize the ensemble predictions
plt.figure(figsize=(12, 6))
plt.plot(new_y_test, label='Actual Moves', color='#6699ff', linewidth=2)
plt.plot(ensemble_predictions, label='Ensemble Forecasted', color='purple')
plt.xlabel('Week')
plt.ylabel('Moves Over Time')
plt.title("Ensemble LSTM Model")
plt.legend()
plt.show()

# Report performance metrics for the ensemble
ensemble_mse = mean_squared_error(new_y_test, ensemble_predictions)
ensemble_mae = mean_absolute_error(new_y_test, ensemble_predictions)
ensemble_rmse = math.sqrt(ensemble_mse)

print('Ensemble Model Metrics:')
print('MSE: ' + str(ensemble_mse))
print('MAE: ' + str(ensemble_mae))
print('RMSE: ' + str(ensemble_rmse))
# Out:
# Ensemble Model Metrics:
# MSE: 89.7636029118848
# MAE: 7.063285550037161
# RMSE: 9.474365567777339
